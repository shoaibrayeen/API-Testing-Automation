# %% [markdown]
# <a href="https://colab.research.google.com/github/shoaibrayeen/API-Testing-Automation/blob/master/ObjectClassification_Testing_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object Classification Testing 1
# ```cpp
# n_classes = 5
# epochs = 20
# img_width, img_height = 160, 160
# batch_size = 24
# ```

# %% [markdown]
# ### Mount drive to access dataset
#
#
# *   [click](https://drive.google.com/drive/folders/10Uqr_lQUgamXQs5Z43PKwwuCRx6hG52b?usp=sharing) here to see the furniture dataset in drive
# *   create shortcut to the My Drive folder
# *   Run the below code to access from drive and upload to session storage

# %%
from google.colab import drive
from pathlib import Path
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %load_ext autoreload
# %autoreload 2

import sys

from pathlib import Path
base = Path('/gdrive/My Drive/furniture-images/img/')
sys.path.append(str(base))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
zip_path = base/'furniture_images.zip'
# !cp "{zip_path}" .
# !unzip -q furniture_images.zip
# !rm furniture_images.zip
# Out:
# replace furniture-images/img/train/bed/00000001.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ### Import Libraries

# %%
import tensorflow as tf

import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing import image
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
from tensorflow.keras import layers
from tensorflow.keras import Model

from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.applications.inception_v3 import preprocess_input

import os
import random

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# ### Access the downloaded dataset in the colab
# Access the dataset directories and images

# %%
base_dir = 'furniture-images/img'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
category = os.listdir(train_dir)

# %%
# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 1
ncols = 8

# Index for iterating over images
pic_index = 0

# %%
pic_index += 8

for it in category:
  # Set up matplotlib fig, and size it to fit 4x4 pics
  fig = plt.gcf()
  fig.set_size_inches(ncols * 4, nrows * 4)
  train_cat_dir = os.path.join(train_dir, it)
  train_cat_fnames = os.listdir(train_cat_dir)
  next_pix = [os.path.join(train_cat_dir, fname) 
                  for fname in train_cat_fnames[pic_index-8:pic_index]]

  for i, img_path in enumerate(next_pix):
    # Set up subplot; subplot indices start at 1
    sp = plt.subplot(nrows, ncols, i + 1)
    sp.axis('Off') # Don't show axes (or gridlines)

    img = mpimg.imread(img_path)
    plt.imshow(img)

  plt.show()

# %%
train_files = sum([len(files) for i, j, files in os.walk(train_dir)])
val_files = sum([len(files) for i, j, files in os.walk(val_dir)])
print(train_files, val_files)
# Out:
# 4024 423

# %% [markdown]
# Set the hyperparameters

# %%
n_classes = 5
epochs = 20
nb_train_samples = train_files
nb_validation_samples = val_files
num_epochs = epochs



img_width, img_height = 160, 160
train_data_dir = train_dir
validation_data_dir = val_dir
batch_size = 24

# %% [markdown]
# ### Build a Model using tensorflow.keras.layers library
# Model is using 3 convolution hidden layers with filter size 3 and activation function relu. The output layer has 5 output neurons with action function softmax

# %%
# Our input feature map is 160x160x3: 160x160 for the image pixels, and 3 for
# the three color channels: R, G, and B
img_input = layers.Input(shape=(160, 160, 3))

# First convolution extracts 16 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(16, 3, activation='relu')(img_input)
x = layers.MaxPooling2D(2)(x)

# First convolution extracts 32 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(32, 3, activation='relu')(img_input)
x = layers.MaxPooling2D(2)(x)

# Second convolution extracts 64 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

x = layers.BatchNormalization()(x)

# Third convolution extracts 128 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(128, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

x = layers.BatchNormalization()(x)

# %%
# Flatten feature map to a 1-dim tensor so we can add fully connected layers
x = layers.Flatten()(x)

# Create a fully connected layer with ReLU activation and 512 hidden units
x = layers.Dense(512, activation='relu')(x)

# Create a fully connected layer with ReLU activation and 128 hidden units
x = layers.Dense(128, activation='relu')(x)

# Create a fully connected layer with ReLU activation and 32 hidden units
x = layers.Dense(32, activation='relu')(x)

# Create output layer with 5 nodes and softmax activation
output = layers.Dense(5, activation='softmax')(x)

# Create model:
# input = input feature map
# output = input feature map + stacked convolution/maxpooling layers + fully 
# connected layer + sigmoid output layer
model = Model(img_input, output)

# %% [markdown]
# ### Print model summary Plot the model architecture
# Model architecture (model_plot.png image) is saved in the root folder of the session by running the below code.

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
print(model.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  conv2d_8 (Conv2D)           (None, 158, 158, 32)      896
#
#  max_pooling2d_8 (MaxPooling  (None, 79, 79, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 77, 77, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 38, 38, 64)       0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 36, 36, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 18, 18, 128)      0
#  g2D)
#
#  batch_normalization_5 (Batc  (None, 18, 18, 128)      512
#  hNormalization)
#
#  flatten_3 (Flatten)         (None, 41472)             0
#
#  dense_10 (Dense)            (None, 512)               21234176
#
#  dense_11 (Dense)            (None, 128)               65664
#
#  dense_12 (Dense)            (None, 32)                4128
#
#  dense_13 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 21,398,149
# Trainable params: 21,397,765
# Non-trainable params: 384
# _________________________________________________________________
# None

# %% [markdown]
# ### Run the model

# %%
from tensorflow.keras.optimizers import RMSprop
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)


train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 4024 images belonging to 5 classes.
# Found 423 images belonging to 5 classes.

# %%
history = model.fit_generator(train_generator,
                    steps_per_epoch = nb_train_samples // batch_size,
                    validation_data=validation_generator,
                    validation_steps=nb_validation_samples // batch_size,
                    epochs=num_epochs,
                    verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/20
# 167/167 [==============================] - 34s 201ms/step - loss: 1.2789 - accuracy: 0.6220 - val_loss: 1.5540 - val_accuracy: 0.3358
# Epoch 2/20
# 167/167 [==============================] - 31s 187ms/step - loss: 0.7359 - accuracy: 0.7437 - val_loss: 0.7611 - val_accuracy: 0.7255
# Epoch 3/20
# 167/167 [==============================] - 33s 198ms/step - loss: 0.5245 - accuracy: 0.8242 - val_loss: 0.6583 - val_accuracy: 0.8015
# Epoch 4/20
# 167/167 [==============================] - 32s 194ms/step - loss: 0.4202 - accuracy: 0.8600 - val_loss: 0.6653 - val_accuracy: 0.8015
# Epoch 5/20
# 167/167 [==============================] - 33s 197ms/step - loss: 0.3367 - accuracy: 0.8905 - val_loss: 0.4921 - val_accuracy: 0.8529
# Epoch 6/20
# 167/167 [==============================] - 32s 189ms/step - loss: 0.2360 - accuracy: 0.9260 - val_loss: 0.5324 - val_accuracy: 0.8456
# Epoch 7/20
# 167/167 [==============================] - 33s 199ms/step - loss: 0.2025 - accuracy: 0.9337 - val_loss: 0.3817 - val_accuracy: 0.8775
# Epoch 8/20
# 167/167 [==============================] - 33s 198ms/step - loss: 0.1628 - accuracy: 0.9488 - val_loss: 0.6025 - val_accuracy: 0.8676
# Epoch 9/20
# 167/167 [==============================] - 31s 188ms/step - loss: 0.1630 - accuracy: 0.9467 - val_loss: 0.5445 - val_accuracy: 0.8701
# Epoch 10/20
# 167/167 [==============================] - 31s 188ms/step - loss: 0.1205 - accuracy: 0.9615 - val_loss: 0.4940 - val_accuracy: 0.8701
# Epoch 11/20
# 167/167 [==============================] - 31s 187ms/step - loss: 0.1142 - accuracy: 0.9628 - val_loss: 0.3356 - val_accuracy: 0.9020
# Epoch 12/20
# 167/167 [==============================] - 34s 203ms/step - loss: 0.0997 - accuracy: 0.9670 - val_loss: 0.5468 - val_accuracy: 0.8750
# Epoch 13/20
# 167/167 [==============================] - 31s 188ms/step - loss: 0.0953 - accuracy: 0.9715 - val_loss: 0.4379 - val_accuracy: 0.8922
# Epoch 14/20
# 167/167 [==============================] - 31s 188ms/step - loss: 0.1222 - accuracy: 0.9610 - val_loss: 0.7469 - val_accuracy: 0.8088
# Epoch 15/20
# 167/167 [==============================] - 31s 188ms/step - loss: 0.0745 - accuracy: 0.9785 - val_loss: 0.5095 - val_accuracy: 0.8750
# Epoch 16/20
# 167/167 [==============================] - 31s 187ms/step - loss: 0.0705 - accuracy: 0.9787 - val_loss: 0.4999 - val_accuracy: 0.8873
# Epoch 17/20
# 167/167 [==============================] - 31s 187ms/step - loss: 0.0826 - accuracy: 0.9765 - val_loss: 0.6185 - val_accuracy: 0.8652
# Epoch 18/20
# 167/167 [==============================] - 31s 188ms/step - loss: 0.0718 - accuracy: 0.9775 - val_loss: 0.4754 - val_accuracy: 0.8725
# Epoch 19/20
# 167/167 [==============================] - 32s 190ms/step - loss: 0.0467 - accuracy: 0.9872 - val_loss: 0.5368 - val_accuracy: 0.8971
# Epoch 20/20
# 167/167 [==============================] - 32s 190ms/step - loss: 0.0730 - accuracy: 0.9820 - val_loss: 0.5649 - val_accuracy: 0.8603

# %% [markdown]
# ### Plot the Results
# Show the accuracy and loss variations per epoch in the graph

# %%
history.history
# Out:
# {'accuracy': [0.621999979019165,
#   0.7437499761581421,
#   0.8242499828338623,
#   0.8600000143051147,
#   0.890500009059906,
#   0.9259999990463257,
#   0.9337499737739563,
#   0.9487500190734863,
#   0.9467499852180481,
#   0.9614999890327454,
#   0.9627500176429749,
#   0.9670000076293945,
#   0.9714999794960022,
#   0.9610000252723694,
#   0.9785000085830688,
#   0.9787499904632568,
#   0.9764999747276306,
#   0.9775000214576721,
#   0.9872499704360962,
#   0.9819999933242798],
#  'loss': [1.2788816690444946,
#   0.7359254956245422,
#   0.5245394706726074,
#   0.42015591263771057,
#   0.33671605587005615,
#   0.2359626144170761,
#   0.20254287123680115,
#   0.16279219090938568,
#   0.16299761831760406,
#   0.12046708911657333,
#   0.1142471581697464,
#   0.09974591434001923,
#   0.09532587230205536,
#   0.12217811495065689,
#   0.07450328022241592,
#   0.07048265635967255,
#   0.08262614160776138,
#   0.07177355140447617,
#   0.046701569110155106,
#   0.07304766774177551],
#  'val_accuracy': [0.33578431606292725,
#   0.7254902124404907,
#   0.8014705777168274,
#   0.8014705777168274,
#   0.8529411554336548,
#   0.845588207244873,
#   0.8774510025978088,
#   0.8676470518112183,
#   0.8700980544090271,
#   0.8700980544090271,
#   0.9019607901573181,
#   0.875,
#   0.8921568393707275,
#   0.8088235259056091,
#   0.875,
#   0.8872548937797546,
#   0.8651960492134094,
#   0.8725489974021912,
#   0.8970588445663452,
#   0.8602941036224365],
#  'val_loss': [1.5540103912353516,
#   0.7611081004142761,
#   0.6582705974578857,
#   0.6652872562408447,
#   0.49212998151779175,
#   0.5324128866195679,
#   0.38173457980155945,
#   0.6025236248970032,
#   0.5444746613502502,
#   0.49397704005241394,
#   0.3356078267097473,
#   0.5468415021896362,
#   0.43793439865112305,
#   0.7469473481178284,
#   0.5095207691192627,
#   0.49989181756973267,
#   0.6185048818588257,
#   0.47538113594055176,
#   0.5367687940597534,
#   0.5648573040962219]}

# %%
def plot_accuracy(history,title):
    plt.title(title)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train_accuracy', 'validation_accuracy'], loc='best')
    plt.show()


def plot_loss(history,title):
    plt.title(title)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train_loss', 'validation_loss'], loc='best')
    plt.show()


plot_accuracy(history,'Furniture-Classification - Accuracy')
plot_loss(history,'Furniture-Classification - Loss')
